# %%
# Importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import os
import glob
from tqdm import tqdm
import tensorflow as tf
import keras
import numpy as np
import cv2
import seaborn as sns
import random
from PIL import Image
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from numpy.random import seed

# %%
# Reading the data
path = '../input/skin-cancer-mnist-ham10000/'
images_path = {os.path.splitext(os.path.basename(x))[0]:x for x in glob.glob(os.path.join(path,'*','*.jpg'))}

# %%
# Encoding target values
lesion_type_dict = {
    'nv':'Melanocytic Nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
    
}

# %%
skin_df = pd.read_csv('../input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

# %%
# Adding extra columns and appending the required created columns in final dataframe
skin_df['path'] = skin_df['image_id'].map(images_path.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get)
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %%
# Image Reading and Resizing.
IMAGE_SIZE = 32
def read_img(img_path):
  img = cv2.imread(img_path,cv2.IMREAD_COLOR)
  img = cv2.resize(img,(IMAGE_SIZE,IMAGE_SIZE))
  return img
train_img = []
for img_name in tqdm(skin_df['path'].values):
  train_img.append(read_img(img_name))
# Out:
# 100%|██████████| 10015/10015 [03:09<00:00, 52.78it/s]

# %%
#Visulaizing the images
plt.figure(figsize=(25,25))
for i in range(1,6,1):
    plt.subplot(1,5,i)
    plt.imshow(train_img[i])
    plt.axis('off')
plt.show()

# %%
# Converting it into float arrays and normalizing it
X = np.array(train_img,np.float32)/255
print(X.shape)
# Out:
# (10015, 32, 32, 3)

# %%
y = np.array(skin_df['cell_type_idx'])

# %%
# Splitting the data
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

x_train,x_val,y_train,y_val =   train_test_split(x_train,y_train,test_size=0.20,random_state=42)

# %%
# One-Hot Encoding values
from keras.utils.np_utils import to_categorical
y_train = to_categorical(y_train, num_classes = 7)
y_val = to_categorical(y_val , num_classes=7)
y_test=to_categorical(y_test , num_classes=7)

# %%
num_classes = 7
input_shape = (32, 32, 3)

# %%
weight_decay = 0.0001
learning_rate = 0.001
label_smoothing = 0.1
validation_split = 0.2
batch_size = 128
num_epochs = 100
patch_size = 2  # Size of the patches to be extracted from the input images.
num_patches = (input_shape[0] // patch_size) ** 2  # Number of patch
embedding_dim = 64  # Number of hidden units.
mlp_dim = 64
dim_coefficient = 4
num_heads = 4
attention_dropout = 0.2
projection_dropout = 0.2
num_transformer_blocks = 8  # Number of repetitions of the transformer layer

print(f"Patch size: {patch_size} X {patch_size} = {patch_size ** 2} ")
print(f"Patches per image: {num_patches}")
# Out:
# Patch size: 2 X 2 = 4
# Patches per image: 256

# %%
data_augmentation = keras.Sequential(
    [
        layers.Normalization(),
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(factor=0.1),
        layers.RandomContrast(factor=0.1),
        layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    ],
    name="data_augmentation",
)
# Compute the mean and the variance of the training data for normalization.
data_augmentation.layers[0].adapt(x_train)

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super(PatchExtract, self).__init__(**kwargs)
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size, self.patch_size, 1),
            strides=(1, self.patch_size, self.patch_size, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super(PatchEmbedding, self).__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %%
def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

# %%
def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %%
def get_model(attention_type="external_attention"):
    inputs = layers.Input(shape=input_shape)
    # Image augment
    x = data_augmentation(inputs)
    # Extract patches.
    x = PatchExtract(patch_size)(x)
    # Create patch embedding.
    x = PatchEmbedding(num_patches, embedding_dim)(x)
    # Create Transformer block.
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(
            x,
            embedding_dim,
            mlp_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
            attention_type,
        )

    x = layers.GlobalAvgPool1D()(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = get_model(attention_type="external_attention")

model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
)
# Out:
# Epoch 1/100
# 36/36 [==============================] - 21s 262ms/step - loss: 1.3768 - accuracy: 0.6268 - top-5-accuracy: 0.9539 - val_loss: 1.3369 - val_accuracy: 0.6480 - val_top-5-accuracy: 0.9501
# Epoch 2/100
# 36/36 [==============================] - 8s 212ms/step - loss: 1.1528 - accuracy: 0.6708 - top-5-accuracy: 0.9677 - val_loss: 1.2577 - val_accuracy: 0.6444 - val_top-5-accuracy: 0.9724
# Epoch 3/100
# 36/36 [==============================] - 8s 213ms/step - loss: 1.1366 - accuracy: 0.6728 - top-5-accuracy: 0.9773 - val_loss: 1.1770 - val_accuracy: 0.6640 - val_top-5-accuracy: 0.9590
# Epoch 4/100
# 36/36 [==============================] - 8s 213ms/step - loss: 1.1048 - accuracy: 0.6826 - top-5-accuracy: 0.9795 - val_loss: 1.2330 - val_accuracy: 0.6239 - val_top-5-accuracy: 0.9626
# Epoch 5/100
# 36/36 [==============================] - 8s 212ms/step - loss: 1.1030 - accuracy: 0.6714 - top-5-accuracy: 0.9817 - val_loss: 1.1575 - val_accuracy: 0.6720 - val_top-5-accuracy: 0.9652
# Epoch 6/100
# 36/36 [==============================] - 8s 213ms/step - loss: 1.0675 - accuracy: 0.7004 - top-5-accuracy: 0.9808 - val_loss: 1.2238 - val_accuracy: 0.6756 - val_top-5-accuracy: 0.9706
# Epoch 7/100
# 36/36 [==============================] - 8s 211ms/step - loss: 1.0581 - accuracy: 0.6975 - top-5-accuracy: 0.9835 - val_loss: 1.1494 - val_accuracy: 0.6800 - val_top-5-accuracy: 0.9688
# Epoch 8/100
# 36/36 [==============================] - 8s 214ms/step - loss: 1.0440 - accuracy: 0.7071 - top-5-accuracy: 0.9842 - val_loss: 1.1013 - val_accuracy: 0.6783 - val_top-5-accuracy: 0.9750
# Epoch 9/100
# 36/36 [==============================] - 8s 211ms/step - loss: 1.0446 - accuracy: 0.7049 - top-5-accuracy: 0.9835 - val_loss: 1.1217 - val_accuracy: 0.6881 - val_top-5-accuracy: 0.9822
# Epoch 10/100
# 36/36 [==============================] - 8s 210ms/step - loss: 1.0324 - accuracy: 0.7075 - top-5-accuracy: 0.9857 - val_loss: 1.0731 - val_accuracy: 0.6988 - val_top-5-accuracy: 0.9795
# Epoch 11/100
# 36/36 [==============================] - 8s 210ms/step - loss: 1.0336 - accuracy: 0.7109 - top-5-accuracy: 0.9857 - val_loss: 1.1491 - val_accuracy: 0.6943 - val_top-5-accuracy: 0.9777
# Epoch 12/100
# 36/36 [==============================] - 8s 215ms/step - loss: 1.0135 - accuracy: 0.7218 - top-5-accuracy: 0.9877 - val_loss: 1.0771 - val_accuracy: 0.7041 - val_top-5-accuracy: 0.9813
# Epoch 13/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9939 - accuracy: 0.7258 - top-5-accuracy: 0.9880 - val_loss: 1.1048 - val_accuracy: 0.6898 - val_top-5-accuracy: 0.9759
# Epoch 14/100
# 36/36 [==============================] - 8s 210ms/step - loss: 1.0122 - accuracy: 0.7231 - top-5-accuracy: 0.9864 - val_loss: 1.0740 - val_accuracy: 0.6889 - val_top-5-accuracy: 0.9786
# Epoch 15/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9894 - accuracy: 0.7370 - top-5-accuracy: 0.9891 - val_loss: 1.1196 - val_accuracy: 0.6622 - val_top-5-accuracy: 0.9786
# Epoch 16/100
# 36/36 [==============================] - 8s 217ms/step - loss: 0.9979 - accuracy: 0.7249 - top-5-accuracy: 0.9897 - val_loss: 1.0745 - val_accuracy: 0.6898 - val_top-5-accuracy: 0.9840
# Epoch 17/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.9851 - accuracy: 0.7381 - top-5-accuracy: 0.9902 - val_loss: 1.0411 - val_accuracy: 0.7175 - val_top-5-accuracy: 0.9840
# Epoch 18/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9799 - accuracy: 0.7419 - top-5-accuracy: 0.9913 - val_loss: 1.0657 - val_accuracy: 0.6970 - val_top-5-accuracy: 0.9840
# Epoch 19/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.9729 - accuracy: 0.7332 - top-5-accuracy: 0.9915 - val_loss: 1.1436 - val_accuracy: 0.6631 - val_top-5-accuracy: 0.9831
# Epoch 20/100
# 36/36 [==============================] - 8s 215ms/step - loss: 0.9751 - accuracy: 0.7419 - top-5-accuracy: 0.9918 - val_loss: 1.0425 - val_accuracy: 0.7166 - val_top-5-accuracy: 0.9840
# Epoch 21/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9686 - accuracy: 0.7428 - top-5-accuracy: 0.9924 - val_loss: 1.0123 - val_accuracy: 0.7193 - val_top-5-accuracy: 0.9875
# Epoch 22/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9522 - accuracy: 0.7425 - top-5-accuracy: 0.9931 - val_loss: 1.0604 - val_accuracy: 0.7175 - val_top-5-accuracy: 0.9848
# Epoch 23/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9580 - accuracy: 0.7465 - top-5-accuracy: 0.9929 - val_loss: 1.0473 - val_accuracy: 0.7130 - val_top-5-accuracy: 0.9857
# Epoch 24/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.9638 - accuracy: 0.7419 - top-5-accuracy: 0.9933 - val_loss: 0.9999 - val_accuracy: 0.7308 - val_top-5-accuracy: 0.9884
# Epoch 25/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.9402 - accuracy: 0.7581 - top-5-accuracy: 0.9935 - val_loss: 1.0813 - val_accuracy: 0.6970 - val_top-5-accuracy: 0.9866
# Epoch 26/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9639 - accuracy: 0.7517 - top-5-accuracy: 0.9938 - val_loss: 1.0491 - val_accuracy: 0.6925 - val_top-5-accuracy: 0.9920
# Epoch 27/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9369 - accuracy: 0.7597 - top-5-accuracy: 0.9942 - val_loss: 1.0522 - val_accuracy: 0.6979 - val_top-5-accuracy: 0.9884
# Epoch 28/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9396 - accuracy: 0.7568 - top-5-accuracy: 0.9935 - val_loss: 1.0034 - val_accuracy: 0.7406 - val_top-5-accuracy: 0.9902
# Epoch 29/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.9231 - accuracy: 0.7635 - top-5-accuracy: 0.9933 - val_loss: 1.0416 - val_accuracy: 0.7068 - val_top-5-accuracy: 0.9857
# Epoch 30/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.9264 - accuracy: 0.7637 - top-5-accuracy: 0.9931 - val_loss: 1.0265 - val_accuracy: 0.7068 - val_top-5-accuracy: 0.9929
# Epoch 31/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9207 - accuracy: 0.7679 - top-5-accuracy: 0.9949 - val_loss: 1.0550 - val_accuracy: 0.6970 - val_top-5-accuracy: 0.9929
# Epoch 32/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9329 - accuracy: 0.7575 - top-5-accuracy: 0.9935 - val_loss: 1.0293 - val_accuracy: 0.7193 - val_top-5-accuracy: 0.9920
# Epoch 33/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9057 - accuracy: 0.7791 - top-5-accuracy: 0.9960 - val_loss: 1.0288 - val_accuracy: 0.7317 - val_top-5-accuracy: 0.9875
# Epoch 34/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9174 - accuracy: 0.7731 - top-5-accuracy: 0.9935 - val_loss: 0.9884 - val_accuracy: 0.7380 - val_top-5-accuracy: 0.9929
# Epoch 35/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.9033 - accuracy: 0.7746 - top-5-accuracy: 0.9942 - val_loss: 1.0065 - val_accuracy: 0.7469 - val_top-5-accuracy: 0.9911
# Epoch 36/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.9224 - accuracy: 0.7635 - top-5-accuracy: 0.9949 - val_loss: 0.9789 - val_accuracy: 0.7496 - val_top-5-accuracy: 0.9902
# Epoch 37/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.9001 - accuracy: 0.7775 - top-5-accuracy: 0.9971 - val_loss: 1.0350 - val_accuracy: 0.7157 - val_top-5-accuracy: 0.9920
# Epoch 38/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8980 - accuracy: 0.7746 - top-5-accuracy: 0.9951 - val_loss: 0.9866 - val_accuracy: 0.7353 - val_top-5-accuracy: 0.9947
# Epoch 39/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8915 - accuracy: 0.7804 - top-5-accuracy: 0.9962 - val_loss: 1.0407 - val_accuracy: 0.7077 - val_top-5-accuracy: 0.9929
# Epoch 40/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.9026 - accuracy: 0.7679 - top-5-accuracy: 0.9940 - val_loss: 1.0056 - val_accuracy: 0.7362 - val_top-5-accuracy: 0.9955
# Epoch 41/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.9000 - accuracy: 0.7728 - top-5-accuracy: 0.9947 - val_loss: 1.0112 - val_accuracy: 0.7380 - val_top-5-accuracy: 0.9920
# Epoch 42/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8905 - accuracy: 0.7813 - top-5-accuracy: 0.9964 - val_loss: 1.0653 - val_accuracy: 0.6898 - val_top-5-accuracy: 0.9955
# Epoch 43/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.9019 - accuracy: 0.7735 - top-5-accuracy: 0.9953 - val_loss: 0.9880 - val_accuracy: 0.7433 - val_top-5-accuracy: 0.9911
# Epoch 44/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8775 - accuracy: 0.7880 - top-5-accuracy: 0.9958 - val_loss: 0.9832 - val_accuracy: 0.7415 - val_top-5-accuracy: 0.9929
# Epoch 45/100
# 36/36 [==============================] - 8s 217ms/step - loss: 0.8890 - accuracy: 0.7793 - top-5-accuracy: 0.9962 - val_loss: 1.0602 - val_accuracy: 0.7086 - val_top-5-accuracy: 0.9920
# Epoch 46/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.9110 - accuracy: 0.7702 - top-5-accuracy: 0.9944 - val_loss: 0.9925 - val_accuracy: 0.7504 - val_top-5-accuracy: 0.9920
# Epoch 47/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8865 - accuracy: 0.7820 - top-5-accuracy: 0.9967 - val_loss: 1.0221 - val_accuracy: 0.7389 - val_top-5-accuracy: 0.9920
# Epoch 48/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8988 - accuracy: 0.7728 - top-5-accuracy: 0.9960 - val_loss: 0.9782 - val_accuracy: 0.7487 - val_top-5-accuracy: 0.9947
# Epoch 49/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.8654 - accuracy: 0.7916 - top-5-accuracy: 0.9964 - val_loss: 1.0078 - val_accuracy: 0.7451 - val_top-5-accuracy: 0.9911
# Epoch 50/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8617 - accuracy: 0.7974 - top-5-accuracy: 0.9980 - val_loss: 0.9801 - val_accuracy: 0.7540 - val_top-5-accuracy: 0.9938
# Epoch 51/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8656 - accuracy: 0.7954 - top-5-accuracy: 0.9962 - val_loss: 1.1048 - val_accuracy: 0.6952 - val_top-5-accuracy: 0.9902
# Epoch 52/100
# 36/36 [==============================] - 8s 213ms/step - loss: 0.8705 - accuracy: 0.7880 - top-5-accuracy: 0.9975 - val_loss: 1.1544 - val_accuracy: 0.6720 - val_top-5-accuracy: 0.9884
# Epoch 53/100
# 36/36 [==============================] - 8s 213ms/step - loss: 0.8702 - accuracy: 0.7907 - top-5-accuracy: 0.9967 - val_loss: 1.0381 - val_accuracy: 0.7148 - val_top-5-accuracy: 0.9920
# Epoch 54/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8596 - accuracy: 0.7963 - top-5-accuracy: 0.9980 - val_loss: 1.0578 - val_accuracy: 0.7077 - val_top-5-accuracy: 0.9911
# Epoch 55/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8456 - accuracy: 0.8018 - top-5-accuracy: 0.9975 - val_loss: 0.9651 - val_accuracy: 0.7567 - val_top-5-accuracy: 0.9920
# Epoch 56/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8447 - accuracy: 0.8036 - top-5-accuracy: 0.9975 - val_loss: 1.0995 - val_accuracy: 0.7130 - val_top-5-accuracy: 0.9884
# Epoch 57/100
# 36/36 [==============================] - 8s 216ms/step - loss: 0.8835 - accuracy: 0.7802 - top-5-accuracy: 0.9947 - val_loss: 1.0605 - val_accuracy: 0.7148 - val_top-5-accuracy: 0.9911
# Epoch 58/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8570 - accuracy: 0.7963 - top-5-accuracy: 0.9973 - val_loss: 1.0134 - val_accuracy: 0.7504 - val_top-5-accuracy: 0.9902
# Epoch 59/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8580 - accuracy: 0.7898 - top-5-accuracy: 0.9962 - val_loss: 1.0441 - val_accuracy: 0.7282 - val_top-5-accuracy: 0.9893
# Epoch 60/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8665 - accuracy: 0.7960 - top-5-accuracy: 0.9978 - val_loss: 1.0535 - val_accuracy: 0.7148 - val_top-5-accuracy: 0.9884
# Epoch 61/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8407 - accuracy: 0.8041 - top-5-accuracy: 0.9973 - val_loss: 1.0101 - val_accuracy: 0.7531 - val_top-5-accuracy: 0.9866
# Epoch 62/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.8268 - accuracy: 0.8159 - top-5-accuracy: 0.9987 - val_loss: 0.9976 - val_accuracy: 0.7522 - val_top-5-accuracy: 0.9866
# Epoch 63/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8312 - accuracy: 0.8101 - top-5-accuracy: 0.9978 - val_loss: 0.9903 - val_accuracy: 0.7522 - val_top-5-accuracy: 0.9938
# Epoch 64/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8260 - accuracy: 0.8107 - top-5-accuracy: 0.9980 - val_loss: 0.9733 - val_accuracy: 0.7576 - val_top-5-accuracy: 0.9929
# Epoch 65/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8426 - accuracy: 0.8087 - top-5-accuracy: 0.9969 - val_loss: 1.0607 - val_accuracy: 0.7086 - val_top-5-accuracy: 0.9902
# Epoch 66/100
# 36/36 [==============================] - 8s 213ms/step - loss: 0.8366 - accuracy: 0.8067 - top-5-accuracy: 0.9982 - val_loss: 1.0419 - val_accuracy: 0.7237 - val_top-5-accuracy: 0.9866
# Epoch 67/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8338 - accuracy: 0.8141 - top-5-accuracy: 0.9969 - val_loss: 1.0151 - val_accuracy: 0.7460 - val_top-5-accuracy: 0.9929
# Epoch 68/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8362 - accuracy: 0.8103 - top-5-accuracy: 0.9980 - val_loss: 1.0204 - val_accuracy: 0.7362 - val_top-5-accuracy: 0.9911
# Epoch 69/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.8140 - accuracy: 0.8190 - top-5-accuracy: 0.9982 - val_loss: 0.9619 - val_accuracy: 0.7629 - val_top-5-accuracy: 0.9929
# Epoch 70/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.8472 - accuracy: 0.8014 - top-5-accuracy: 0.9962 - val_loss: 1.0401 - val_accuracy: 0.7389 - val_top-5-accuracy: 0.9866
# Epoch 71/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8220 - accuracy: 0.8134 - top-5-accuracy: 0.9980 - val_loss: 0.9657 - val_accuracy: 0.7683 - val_top-5-accuracy: 0.9938
# Epoch 72/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.8283 - accuracy: 0.8052 - top-5-accuracy: 0.9982 - val_loss: 0.9959 - val_accuracy: 0.7478 - val_top-5-accuracy: 0.9848
# Epoch 73/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.8169 - accuracy: 0.8130 - top-5-accuracy: 0.9980 - val_loss: 1.0445 - val_accuracy: 0.7291 - val_top-5-accuracy: 0.9893
# Epoch 74/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.8149 - accuracy: 0.8199 - top-5-accuracy: 0.9978 - val_loss: 1.0045 - val_accuracy: 0.7522 - val_top-5-accuracy: 0.9929
# Epoch 75/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8012 - accuracy: 0.8194 - top-5-accuracy: 0.9991 - val_loss: 1.0053 - val_accuracy: 0.7469 - val_top-5-accuracy: 0.9938
# Epoch 76/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7976 - accuracy: 0.8286 - top-5-accuracy: 0.9980 - val_loss: 1.1209 - val_accuracy: 0.7086 - val_top-5-accuracy: 0.9840
# Epoch 77/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7850 - accuracy: 0.8350 - top-5-accuracy: 0.9984 - val_loss: 1.0655 - val_accuracy: 0.7317 - val_top-5-accuracy: 0.9893
# Epoch 78/100
# 36/36 [==============================] - 8s 215ms/step - loss: 0.7832 - accuracy: 0.8299 - top-5-accuracy: 0.9984 - val_loss: 1.0387 - val_accuracy: 0.7442 - val_top-5-accuracy: 0.9911
# Epoch 79/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.8039 - accuracy: 0.8250 - top-5-accuracy: 0.9982 - val_loss: 0.9914 - val_accuracy: 0.7576 - val_top-5-accuracy: 0.9822
# Epoch 80/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7794 - accuracy: 0.8330 - top-5-accuracy: 1.0000 - val_loss: 1.1085 - val_accuracy: 0.6996 - val_top-5-accuracy: 0.9902
# Epoch 81/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8033 - accuracy: 0.8217 - top-5-accuracy: 0.9978 - val_loss: 0.9904 - val_accuracy: 0.7576 - val_top-5-accuracy: 0.9893
# Epoch 82/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.7838 - accuracy: 0.8304 - top-5-accuracy: 0.9989 - val_loss: 1.1194 - val_accuracy: 0.7228 - val_top-5-accuracy: 0.9795
# Epoch 83/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7830 - accuracy: 0.8362 - top-5-accuracy: 0.9984 - val_loss: 1.0273 - val_accuracy: 0.7424 - val_top-5-accuracy: 0.9893
# Epoch 84/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7867 - accuracy: 0.8368 - top-5-accuracy: 0.9989 - val_loss: 1.0256 - val_accuracy: 0.7371 - val_top-5-accuracy: 0.9857
# Epoch 85/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.7678 - accuracy: 0.8442 - top-5-accuracy: 0.9993 - val_loss: 1.1264 - val_accuracy: 0.7237 - val_top-5-accuracy: 0.9848
# Epoch 86/100
# 36/36 [==============================] - 8s 214ms/step - loss: 0.7844 - accuracy: 0.8324 - top-5-accuracy: 0.9993 - val_loss: 1.0395 - val_accuracy: 0.7709 - val_top-5-accuracy: 0.9822
# Epoch 87/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7764 - accuracy: 0.8393 - top-5-accuracy: 0.9987 - val_loss: 1.0827 - val_accuracy: 0.7219 - val_top-5-accuracy: 0.9893
# Epoch 88/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7558 - accuracy: 0.8520 - top-5-accuracy: 0.9989 - val_loss: 1.1740 - val_accuracy: 0.7014 - val_top-5-accuracy: 0.9831
# Epoch 89/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.8431 - accuracy: 0.8007 - top-5-accuracy: 0.9978 - val_loss: 1.0509 - val_accuracy: 0.7282 - val_top-5-accuracy: 0.9848
# Epoch 90/100
# 36/36 [==============================] - 8s 217ms/step - loss: 0.7902 - accuracy: 0.8324 - top-5-accuracy: 0.9982 - val_loss: 1.0142 - val_accuracy: 0.7513 - val_top-5-accuracy: 0.9902
# Epoch 91/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.7663 - accuracy: 0.8473 - top-5-accuracy: 0.9987 - val_loss: 1.0595 - val_accuracy: 0.7255 - val_top-5-accuracy: 0.9884
# Epoch 92/100
# 36/36 [==============================] - 8s 209ms/step - loss: 0.7992 - accuracy: 0.8261 - top-5-accuracy: 0.9987 - val_loss: 1.0518 - val_accuracy: 0.7415 - val_top-5-accuracy: 0.9866
# Epoch 93/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7991 - accuracy: 0.8272 - top-5-accuracy: 0.9987 - val_loss: 0.9523 - val_accuracy: 0.7718 - val_top-5-accuracy: 0.9920
# Epoch 94/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.8122 - accuracy: 0.8277 - top-5-accuracy: 0.9953 - val_loss: 1.0624 - val_accuracy: 0.7362 - val_top-5-accuracy: 0.9840
# Epoch 95/100
# 36/36 [==============================] - 8s 212ms/step - loss: 0.7698 - accuracy: 0.8446 - top-5-accuracy: 0.9996 - val_loss: 1.0379 - val_accuracy: 0.7513 - val_top-5-accuracy: 0.9857
# Epoch 96/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7698 - accuracy: 0.8386 - top-5-accuracy: 0.9996 - val_loss: 1.1832 - val_accuracy: 0.7157 - val_top-5-accuracy: 0.9742
# Epoch 97/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7648 - accuracy: 0.8408 - top-5-accuracy: 0.9989 - val_loss: 1.0487 - val_accuracy: 0.7353 - val_top-5-accuracy: 0.9866
# Epoch 98/100
# 36/36 [==============================] - 8s 210ms/step - loss: 0.7627 - accuracy: 0.8437 - top-5-accuracy: 0.9987 - val_loss: 1.0249 - val_accuracy: 0.7549 - val_top-5-accuracy: 0.9857
# Epoch 99/100
# 36/36 [==============================] - 8s 215ms/step - loss: 0.7323 - accuracy: 0.8602 - top-5-accuracy: 0.9993 - val_loss: 1.0526 - val_accuracy: 0.7567 - val_top-5-accuracy: 0.9875
# Epoch 100/100
# 36/36 [==============================] - 8s 211ms/step - loss: 0.7339 - accuracy: 0.8578 - top-5-accuracy: 0.9991 - val_loss: 1.1459 - val_accuracy: 0.7166 - val_top-5-accuracy: 0.9848

# %%
plt.style.use('seaborn')
plt.figure(figsize=(12,6))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(12,6))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.show()
